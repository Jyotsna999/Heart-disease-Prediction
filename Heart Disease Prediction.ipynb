# %%
import os
os.chdir("C:\\Users\\Jyotsna Nag\\Desktop\\Machine Learning\\Kaggle Projects\\Heart Diesease Prediction")

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data_set=pd.read_csv('heart.csv')
data_set.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
updated_cols = ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'SerumCholestoral', 'FastingBloodSugar', 'RestingECG', 'MaxHeartRate', 'ExeriseEnducedAngina', 'OldPeak', 'SlopeOldPeak', 'MajorVessels', 'Thal', 'Output']
data_set.columns = updated_cols
data_set.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  SerumCholestoral  FastingBloodSugar  \
# 0   63    1              3        145               233                  1
# 1   37    1              2        130               250                  0
# 2   41    0              1        130               204                  0
# 3   56    1              1        120               236                  0
# 4   57    0              0        120               354                  0
#
#    RestingECG  MaxHeartRate  ExeriseEnducedAngina  OldPeak  SlopeOldPeak  \
# 0           0           150                     0      2.3             0
# 1           1           187                     0      3.5             0
# 2           0           172                     0      1.4             2
# 3           1           178                     0      0.8             2
# 4           1           163                     1      0.6             2
#
#    MajorVessels  Thal  Output
# 0             0     1       1
# ...

# %%
data_set.describe()
# Out:
#               Age         Sex  ChestPainType   RestingBP  SerumCholestoral  \
# count  303.000000  303.000000     303.000000  303.000000        303.000000
# mean    54.366337    0.683168       0.966997  131.623762        246.264026
# std      9.082101    0.466011       1.032052   17.538143         51.830751
# min     29.000000    0.000000       0.000000   94.000000        126.000000
# 25%     47.500000    0.000000       0.000000  120.000000        211.000000
# 50%     55.000000    1.000000       1.000000  130.000000        240.000000
# 75%     61.000000    1.000000       2.000000  140.000000        274.500000
# max     77.000000    1.000000       3.000000  200.000000        564.000000
#
#        FastingBloodSugar  RestingECG  MaxHeartRate  ExeriseEnducedAngina  \
# count         303.000000  303.000000    303.000000            303.000000
# mean            0.148515    0.528053    149.646865              0.326733
# ...

# %%
#Plotting Age
plt.figure(figsize=(15,7))
plt.plot(data_set['Age'])
plt.xlabel('No of people')
plt.ylabel('Age')
plt.title('Age Comparision',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Sex',data=data_set)
plt.title('Male vs Female',size=15)
plt.show()
# Male-1,Female-0

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='ChestPainType',data=data_set)
plt.title('Types of Chest Pain',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(data_set['RestingBP'])
plt.title('Resting Blood Pressure Plot',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(data_set["SerumCholestoral"])
plt.xlabel("Number of People")
plt.ylabel("Serum Cholestoral count")
plt.title('Serum Cholestoral')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='FastingBloodSugar',data=data_set)
plt.title('Fasting BLood Sugar',size=15)
plt.show()
#Fasting Blood Sugar>120mg/dl-1 
#Fasting Blood Sugar<120mg/dl-0

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='RestingECG',data=data_set)
plt.title('Resting ECG',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(data_set['MaxHeartRate'])
plt.title('Maximum Heart Rate',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='ExeriseEnducedAngina',data=data_set)
plt.title('Exerise Enduced Angina',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(data_set['OldPeak'])
plt.title('Old Peak',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_set['SlopeOldPeak'])
plt.title('Slope Old Peak',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_set['MajorVessels'])
plt.title('Major Vessels',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_set['Thal'])
plt.title('Thal',size=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Output', data=data_set)
plt.title("Output")
plt.show()

# %%
x=data_set.iloc[:,1:13]
y=data_set.iloc[:,13]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lrmodel=LogisticRegression(random_state=0)
lrmodel.fit(x_train,y_train)
y_predlr=lrmodel.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
cm_lr=confusion_matrix(y_test,y_predlr)
accuracy_score_lr=accuracy_score(y_test,y_predlr)

# %%
plt.figure(figsize=(15,7))
plt.title('LogisticRegression Confusion Matrix',)
sns.heatmap(cm_lr,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of Logistic Regression:{}'.format(accuracy_score_lr))
# Out:
# Accuracy of Logistic Regression:0.8131868131868132

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knnmodel=KNeighborsClassifier()
knnmodel.fit(x_train,y_train)
y_predknn=knnmodel.predict(x_test)

# %%
cm_knn=confusion_matrix(y_test,y_predknn)
accuracy_score_knn=accuracy_score(y_test,y_predknn)

# %%
plt.figure(figsize=(15,7))
plt.title('K Nearest Neighbours Confusion Matrix')
sns.heatmap(cm_knn,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of K Neighbors Classifier:{}'.format(accuracy_score_knn))
# Out:
# Accuracy of K Neighbors Classifier:0.7692307692307693

# %%
#SVM

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear',random_state=0)
svm.fit(x_train,y_train)
y_predsvm=svm.predict(x_test)

# %%
cm_svm=confusion_matrix(y_test,y_predsvm)
accuracy_score_svm=accuracy_score(y_test,y_predsvm)

# %%
plt.figure(figsize=(15,7))
plt.title('SVM Confusion Matrix')
sns.heatmap(cm_svm,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of SVM:{}'.format(accuracy_score_svm))
# Out:
# Accuracy of SVM:0.8021978021978022

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
y_prednb=nb.predict(x_test)

# %%
cm_nb=confusion_matrix(y_test,y_prednb)
accuracy_score_nb=accuracy_score(y_test,y_prednb)

# %%
plt.figure(figsize=(15,7))
plt.title('Naive Bayes Confusion Matrix')
sns.heatmap(cm_nb,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of Naive Bayes:{}'.format(accuracy_score_nb))
# Out:
# Accuracy of Naive Bayes:0.8131868131868132

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion='gini',random_state=0)
tree.fit(x_train,y_train)
y_predtree=tree.predict(x_test)

# %%
cm_tree=confusion_matrix(y_test,y_predtree)
accuracy_score_tree=accuracy_score(y_test,y_predtree)

# %%
plt.figure(figsize=(15,7))
plt.title('Decision Tree Confusion Matrix')
sns.heatmap(cm_tree,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of Decision Trees:{}'.format(accuracy_score_tree))
# Out:
# Accuracy of Decision Trees:0.7142857142857143

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(criterion='gini',n_estimators=10)
forest.fit(x_train,y_train)
y_predforest=forest.predict(x_test)

# %%
cm_forest=confusion_matrix(y_test,y_predforest)
accuracy_score_forest=accuracy_score(y_test,y_predforest)

# %%
plt.figure(figsize=(15,7))
plt.title('Random Forest Confusion Matrix')
sns.heatmap(cm_forest,annot=True,cmap='Blues',fmt='d',cbar=False)
plt.show()

# %%
print('Accuracy of Random Forest:{}'.format(accuracy_score_forest))
# Out:
# Accuracy of Random Forest:0.8571428571428571

# %%
classification_models=['Linear Regression','K Nearest Neighbours','SVM','Naive Bayes','Decision Tree','Random Forest']
model_accuracy=[accuracy_score_lr,accuracy_score_knn,accuracy_score_svm,accuracy_score_nb,accuracy_score_tree,accuracy_score_forest]

# %%
plt.figure(figsize=(15,7))
plt.plot(classification_models,model_accuracy)
plt.ylabel('Accuracy')
plt.show()
